# %% [markdown]
# # SVM Results
#
# Run `python train.py` from the repository root before opening this notebook. The notebook only loads saved predictions and visualizes them; it does not retrain the model.

# %%
# %matplotlib inline
from cuffless_bp.notebook import show_saved_result
metrics, predictions = show_saved_result("svm")
